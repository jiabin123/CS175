# %%
import string
import re
import tensorflow as tf
import keras
from keras import layers
from keras import losses
from keras.models import Sequential
from keras.layers.experimental.preprocessing import TextVectorization

# %%
batch_size = 32
seed = 42

raw_train_ds = keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train',
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
    seed=seed)

# 3 example Reviews:
for text_batch, label_batch in raw_train_ds.take(1):
  for i in range(3):
    print("Review", text_batch.numpy()[i])
    print("Label", label_batch.numpy()[i])

raw_val_ds = keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train',
    batch_size=batch_size,
    validation_split=0.2,
    subset='validation',
    seed=seed)

raw_test_ds = keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test',
    batch_size=batch_size)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Review b'"Pandemonium" is a horror movie spoof that comes off more stupid than funny. Believe me when I tell you, I love comedies. Especially comedy spoofs. "Airplane", "The Naked Gun" trilogy, "Blazing Saddles", "High Anxiety", and "Spaceballs" are some of my favorite comedies that spoof a particular genre. "Pandemonium" is not up there with those films. Most of the scenes in this movie had me sitting there in stunned silence because the movie wasn\'t all that funny. There are a few laughs in the film, but when you watch a comedy, you expect to laugh a lot more than a few times and that\'s all this film has going for it. Geez, "Scream" had more laughs than this film and that was more of a horror film. How bizarre is that?<br /><br />*1/2 (out of four)'
# Label 0
# ...

# %%
# Preprocess data,
# lower, remove: <br />, number (date or rating or word), [anything], punctuation
def custom_standardization(input_data):
  lower = tf.strings.lower(input_data)
  remove_html = tf.strings.regex_replace(lower, '<br />', ' ')
  remove_num = tf.strings.regex_replace(remove_html, '\w*\d\w*', '')
  remove_paren = tf.strings.regex_replace(remove_num, '\[.*?\]', '')
  remove_pun = tf.strings.regex_replace(remove_paren,
                                  '[%s]' % re.escape(string.punctuation),
                                  '')
  return remove_pun

# %%
# Vectorization
max_features = 10000
sequence_length = 600

vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=sequence_length)

# Make a text-only dataset (without labels), then call adapt
train_text = raw_train_ds.map(lambda x, y: x)
vectorize_layer.adapt(train_text)

def vectorize_text(text, label):
  text = tf.expand_dims(text, -1)
  return vectorize_layer(text), label
train_ds = raw_train_ds.map(vectorize_text)
val_ds = raw_val_ds.map(vectorize_text)
test_ds = raw_test_ds.map(vectorize_text)

# %%
#Defining Model
embedding_dim = 16
model = tf.keras.Sequential([
  layers.Embedding(max_features + 1, embedding_dim),
  layers.Dropout(0.2),
  layers.GlobalAveragePooling1D(),
  layers.Dropout(0.2),
  layers.Dense(1)])
LSTM

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 16)          160016
# _________________________________________________________________
# dropout (Dropout)            (None, None, 16)          0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# ...
# Total params: 160,033
# Trainable params: 160,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=losses.BinaryCrossentropy(from_logits=True),
              optimizer='adam',
              metrics=tf.metrics.BinaryAccuracy(threshold=0.0))

# %%
# Training the model
epochs = 10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 14s 20ms/step - loss: 0.6886 - binary_accuracy: 0.5668 - val_loss: 0.6594 - val_binary_accuracy: 0.7118
# Epoch 2/10
# 625/625 [==============================] - 16s 26ms/step - loss: 0.6389 - binary_accuracy: 0.7370 - val_loss: 0.5797 - val_binary_accuracy: 0.7884
# Epoch 3/10
# 625/625 [==============================] - 13s 21ms/step - loss: 0.5532 - binary_accuracy: 0.7986 - val_loss: 0.5051 - val_binary_accuracy: 0.8246
# Epoch 4/10
# 625/625 [==============================] - 15s 24ms/step - loss: 0.4793 - binary_accuracy: 0.8332 - val_loss: 0.4481 - val_binary_accuracy: 0.8460
# Epoch 5/10
# 625/625 [==============================] - 8s 12ms/step - loss: 0.4219 - binary_accuracy: 0.8557 - val_loss: 0.4053 - val_binary_accuracy: 0.8570
# Epoch 6/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.3801 - binary_accuracy: 0.8673 - val_loss: 0.3747 - val_binary_accuracy: 0.8670
# Epoch 7/10
# ...

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_ds)

print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 782/782 [==============================] - 13s 17ms/step - loss: 0.3199 - binary_accuracy: 0.8783
# Loss:  0.31993550062179565
# Accuracy:  0.8783199787139893
